# %%
print("Hola") #Imprime
print('Bienvenido') # Funcion nativa de python
#Esto es un comentario
# Un texto puede ir entre comillas dobles o comillas simples
# Out:
# Hola
# Bienvenido

# %%
nombre=input("¿Cual es tu nombre? ")
# Out:
# ¿Cual es tu nombre? Hector

# %%
print('Hola',nombre, ', Bienvenido')
# Out:
# Hola Hector , Bienvenido

# %%
print('Hola' +nombre+',Bienvenido')
# Out:
# HolaHector,Bienvenido

# %%
type(nombre) # str ->  string (tipo de texto)
# Out:
# str

# %%
numero=100
type(numero)  #int -> integer (Dato de tipo entero)
# Out:
# int

# %%
decimal=3.1416
type(decimal) #foalt -> tipo flotante = numero decimal
# Out:
# float

# %%
logica  = True #verdadero
type(logica)   # bool -> buleano = o es verdadero o falso
# Out:
# bool

# %%
logica  = False #verdadero
type(logica)   # bool -> buleano = o es verdadero o falso
# Out:
# bool

# %%
num1=10 
num2= 2

# %%
5+11+(12*3)
# Out:
# 52

# %%
num1 + num2 #sumar
# Out:
# 12

# %%
num1 - num2 #resta
# Out:
# 8

# %%
num1 * num2  #mulplicacion
# Out:
# 20

# %%
num1/num2 #division    tipo de dato en la division es = a flotante
# Out:
# 5.0

# %%
# // division entera 
#% modulo

# %%
print('Este programa multiplica 2 numeros')
str_num1=input('Escribe el primer numero: ')  #Recuerda que dato que entra es de tipo string y hay que cambiarlo a dato de tipo entero (int)
str_num2=input('Escribe el segundo numero')
int_num1= int(str_num1)
int_num2= int(str_num2)
resultado = int_num1 * int_num2
print('El resultado de', str_num1, 'x' , str_num2, 'es' , resultado)
# El resultado de 23 x 6 es 138

# %%
print('El resultado de:' + str(int_num1))
# Out:
# El resultado de:23

# %%
print('El resultado de {} x {} es {}'.format(int_num1, int_num2,resultado))
# Out:
# El resultado de 23 x 6 es 138

# %%
print('Este programa multiplica 2 numeros')
num1=int(input('Escribe el primer numero: '))
num2=int(input('Escribe el segundo numero'))
print('El resultado de {} x {} es {}'.format(num1, num2,num1*num2))
# Out:
# Este programa multiplica 2 numeros
# Escribe el primer numero: 22
# Escribe el segundo numero4
# El resultado de 22 x 4 es 88

# %%
#Seleccion 'if, elif, else'

if 10>5:
  print('VERDADERO')
else: 
  print('Falso')
# Out:
# VERDADERO

# %%
var = 'Hector'
if var=='Daniel':
  print('eres Daniel')
elif var== 'Hector':
  print('eres Hector')
else:
  print('No eres Daniel ni Hector')

# %%
print('Esta es una calculadora')
print('Elije el tipo de operacion del menu.')
print('1. Sumar')
print('2. Restar')
print('3. Multiplicar')
print('4. Dividir')
res=input('¿Que quieres hacer?')
num1=float(input('Escribe el primer numero: '))
num2=float(input('Escribe el segundo numero '))
if res=='Sumar':
  print('{} + {} = {}'.format(num1,num2,num1+num2))
elif res=='Restar':
  print('{} - {} = {}'.format(num1,num2,num1-num2))
elif res=='Multiplicar':
  print('{} * {} = {}'.format(num1,num2,num1*num2))
elif res=='Dividir':
  print('{} / {} = {}'.format(num1,num2,num1/num2))
else: 
  print('comando no valido')
# Out:
# Esta es una calculadora
# Elije el tipo de operacion del menu.
# 1. Sumar
# 2. Restar
# 3. Multiplicar
# 4. Dividir
# ¿Que quieres hacer?Dividir
# Escribe el primer numero: 15
# Escribe el segundo numero 3
# 15.0 / 3.0 = 5.0

# %%
num1=10
num2=10
if num1==num2:
  print('Son iguales')
elif num1>num2:
  print('El primer es mayor')
elif num1<num2:
  print('El segundo es mayor')
#else es opcional
# Out:
# Son iguales

# %%
num1=10
num2=10
if num1!=num2:
  print('No son iguales')
else:
  print('Son iguales')
# Out:
# Son iguales

# %%
num1=10
num2=10
if num1>=num2:
  print('El primero es mayor o igual')
# Out:
# El primero es mayor o igual

# %%
num1=9
num2=10
if num1<=num2:
  print('El primero es menor o igual')
# Out:
# El primero es menor o igual

# %%
num1=10
num2=10
if num1!=num2:
  print('Son Diferentes')
elif num1>=num2:
  print('El primero es mayor o igual que el segundo')
elif num1==num2:
  print('Son iguales')
else:
  print('Ninguna condicion')
# Out:
# El primero es mayor o igual que el segundo

# %%
num1=10
num2=10
if num1!=num2:
  print('Son Diferentes')
if num1>=num2:
  print('El primero es mayor o igual que el segundo')
if num1==num2:
  print('Son iguales')
else:
  print('Ninguna condicion')
# Out:
# El primero es mayor o igual que el segundo
# Son iguales

# %%
usuario_db= 'Hector'
contraseña_db = 'qwerty'
print('Log In')
usuario_ingresado=input('Nombre de usuario:')
contraseña_ingresada=input('Contraseña:')

if usuario_ingresado == usuario_db:
  print('Usuario encontrado')
  if contraseña_ingresada == contraseña_db:
    print('La contraseña coincide ')
    print('Entraste al sistema')
else:
  print('La contraseña no coincide ')
